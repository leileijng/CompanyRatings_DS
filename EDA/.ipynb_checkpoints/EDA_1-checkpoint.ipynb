# %% [markdown]
# # EDA: Data Visulisation and Analysis
#
# ---
# Exploratory data analysis/visualization to gather relevant insights
#
# ### Essential Libraries
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
import pickle
sb.set() # set the default Seaborn style for graphics

# %%
df = pd.read_pickle('../dataset/data_prepare1.pickle')
df.head()
# Out:
#    rating  reviews                                          happiness  \
# 1     3.4      437                                                NaN
# 2     3.5      367                                                NaN
# 3     4.2      803  {'Work Happiness Score': '76', 'Appreciation':...
# 4     4.1      501  {'Work Happiness Score': '70', 'Learning': '81...
# 5     4.0      183                                                NaN
#
#    ceo_approval  ceo_count                                              roles  \
# 1            57        199  {'Workday HCM Consultant': '5.0', 'Software Te...
# 2            78        167  {'Claims Examiner': '4.7', 'Office Assistant':...
# 3            83        275  {'Mentor': '5.0', 'Intern': '5.0', 'Security C...
# 4            89        181                                                NaN
# 5            76         84  {'Laboratory Assistant': '5.0', 'Senior Resear...
#
#                                               salary  employees  \
# 1  {'Customer Service Representative': '$29.97 pe...          8
# 2  {'Insurance Agent': '$48,284 per year', 'Agent...          7
# 3  {'Graduate Researcher': '$26,598 per year', 'R...          8
# 4  {'Program Coordinator': '$48,016 per year', 'R...          8
# 5                                                NaN          8
#
#         industry  revenue  Work/Life Balance  Compensation/Benefits  \
# 1    Commodities        7                3.4                    3.5
# 2     Financials        7                3.7                    3.3
# 3  Govt_Services        7                4.0                    3.7
# 4  Govt_Services        7                4.1                    3.8
# 5    Commodities        9                4.0                    3.7
#
#    Job Security/Advancement  Management  Culture    avg_salary
# 1                       2.8         2.9      3.2  83730.200000
# 2                       3.2         3.1      3.3  40685.666667
# 3                       3.6         3.7      4.0  36279.933333
# 4                       3.7         3.7      3.9  45855.000000
# 5                       3.4         3.6      3.9           NaN

# %% [markdown]
# ## Statistical Summary for Predictor: Rating

# %%
rating = pd.DataFrame(df['rating'])
print("Data type : ", type(rating))
print("Data dims : ", rating.size)
rating.describe()
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  6476
#             rating
# count  6476.000000
# mean      3.533879
# std       0.423635
# min       1.700000
# 25%       3.300000
# 50%       3.500000
# 75%       3.800000
# max       5.000000

# %%
fig, axs = plt.subplots(1,3,figsize=(20,5))
sb.boxplot(data = rating, ax=axs[0], orient = "h")
sb.histplot(rating, ax=axs[1], bins=10, kde=True)
sb.violinplot(data = rating, ax=axs[2], orient = "h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# ## 1. Exploring Features (Numeric)
# ---
# > Detailed Ratings of Company <br>
# > Happiness-Related Ratings <br>
# > `choose yourself` <br>
#
# ### 1.1 Detailed Ratings of Company
# - Work/Life Balance
# - Compensation/Benefits
# - Job Security/Advancement
# - Management
# - Culture

# %%
fig, axs = plt.subplots(2, 3, figsize=(20,15))
col_index = 0
for i, col in enumerate(['Work/Life Balance', 'Compensation/Benefits', 'Job Security/Advancement', 'Management', 'Culture']):
    row_index = int(i / 3)
    col_index = int(i - (row_index * 3) )
    sb.histplot(df[col], bins=10, ax=axs[row_index,col_index], kde=True)
    #col_index = 0 if col_index else 1

# %%
fig, axs = plt.subplots(figsize=(10,5))
for i, col in enumerate(['Work/Life Balance', 'Compensation/Benefits', 'Job Security/Advancement', 'Management', 'Culture']):
    sb.kdeplot(df[col], label=col)
    
sb.kdeplot(df['rating'], label='Rating')
plt.legend()

# %% [markdown]
# ### Discoveries:
# As expected, the company-related ratings (worklife balance, compensation, advancement, management, culture) have similar distribution as rating (predictor), leading to the further exploration on their correlations.

# %%
fig, axs = plt.subplots(figsize=(10,6))
jointDF_rating = pd.concat([df['rating'],
                               df['Compensation/Benefits'],
                               df['Job Security/Advancement'],
                               df['Management'],
                               df['Culture'],
                               df['Work/Life Balance'],], axis = 1).reindex()
sb.heatmap(jointDF_rating.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Discoveries:
# Surprisingly, all perspectives have strong positive correlation (>=0.9) with company ratings except the compensation/benefit (0.72).
# - So, which feature has the heaviest weightage in affecting company's rating?

# %% [markdown]
# ---
#
# ### 1.2. Happiness-Related Ratings
# - Work Happiness Score
# - Appreciation
# - Purpose
# - Learning
# - Support
# - Achievement
# - Flexibility
# - Trust
# - Energy
# - Inclusion
# - Belonging
# - Management
# - Compensation

# %%
df2 = pd.read_pickle('../dataset/data_prepare2.pickle')
df2.head()
# Out:
#    rating  reviews  ceo_approval  ceo_count  \
# 1     4.2      803            83        275
# 2     4.1      501            89        181
# 3     3.9      167            90         79
# 4     2.7      541            41        233
# 5     3.2      271            58        117
#
#                                                roles  \
# 1  {'Mentor': '5.0', 'Intern': '5.0', 'Security C...
# 2                                                NaN
# 3  {'Director of Human Resources': '5.0', 'Food R...
# 4  {'Technician': '3.8', 'Personal Technology Exp...
# 5  {'Bookkeeper': '4.3', 'Delivery Specialist': '...
#
#                                               salary  employees  \
# 1  {'Graduate Researcher': '$26,598 per year', 'R...          8
# 2  {'Program Coordinator': '$48,016 per year', 'R...          8
# 3  {'Housekeeper': '$12.57 per hour', 'Attendant'...          8
# 4  {'Service Technician': '$10.49 per hour', 'Des...          7
# 5  {'Yard Worker': '$8.14 per hour', 'Yard Specia...          7
#
#         industry  revenue  Work/Life Balance  ...  Learning  Support  \
# 1  Govt_Services        7                4.0  ...        78       77
# 2  Govt_Services        7                4.1  ...        81       76
# 3        Leisure        5                3.6  ...        71       70
# 4           Tech        4                2.8  ...        52       52
# 5    Real_Estate        7                3.2  ...        65       60
#
#    Achievement  Flexibility  Trust  Energy  Inclusion  Belonging  Management  \
# 1           75           74     72      72         72         70          69
# 2           76           77     70      76         74         71          70
# 3           73           69     67      73         66         68          65
# 4           57           53     45      43         50         40          51
# 5           67           67     57      64         55         56          51
#
#    Compensation
# 1            68
# 2            66
# 3            64
# 4            40
# 5            58
#
# [5 rows x 28 columns]

# %%
sb.jointplot(data = df2, x='Work Happiness Score', y='rating', height = 8)

# %%
# Calculate the correlation between the two columns/variables
pd.concat([df2['Work Happiness Score'],df2['rating']], axis = 1).reindex().corr()
# Out:
#                       Work Happiness Score    rating
# Work Happiness Score              1.000000  0.758429
# rating                            0.758429  1.000000

# %%
jointDF_rating2 = pd.concat([df2['Work Happiness Score'],
                            df2['Appreciation'],
                            df2['Purpose'],
                            df2['Learning'],
                            df2['Support'],
                            df2['Achievement'],
                            df2['Flexibility'],
                            df2['Trust'],
                            df2['Energy'],
                            df2['Inclusion'],
                            df2['Belonging'],
                            df2['Compensation']
                           ], axis = 1).reindex()

fig, axs = plt.subplots(figsize=(10,6))
sb.heatmap(jointDF_rating2.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Discoveries:
# 1. The working happiness has strong positive correlation with company rating, corr = `0.758429`
# 2. The working happiness are found to have strong positive correlation with many aspects, except compensation `0.66` only, aligning with our discoveries in 1.1

# %% [markdown]
# ---
#
# ### 1.3. Salaries / CEO (approvals) / reviews
#
# if you choose salaries, then need to handle the data (take average per week for all) <br>
# if you choose ceo approvals, i think it may be easy, just see the trend (bi-variate) <br>
# if you chooes reviews, it will be easy, but i dont think these 2 are related tho

# %%
sb.jointplot(data = df, x='ceo_approval', y='rating', height = 8)

# %%
pd.concat([df['ceo_approval'],df['rating']], axis = 1).reindex().corr()
# Out:
#               ceo_approval    rating
# ceo_approval      1.000000  0.717717
# rating            0.717717  1.000000

# %% [markdown]
# ## Salaries

# %%
sb.jointplot(data = df, x='avg_salary', y='rating')

# %%
pd.concat([df['avg_salary'],df['rating']], axis = 1).reindex().corr()
# Out:
#             avg_salary    rating
# avg_salary    1.000000  0.139851
# rating        0.139851  1.000000

# %% [markdown]
# ---
# ---
#
# ## 2. Exploring Features (Categorical)
# > Employees (Company Size) <br>
# > Company Revenue <br>
# > Industry <br>
#
# ----
#
# ### 2.1. Employees (Company Size)
# | Label  |Description       | Count       |
# | :---                | :---: | :----: |
# | 1   |  1             |    6    |
# | 2   |  2 to 10       |   66    |
# | 3   |  11 to 50      |   101   |
# | 4   |  51 to 200     |   365   |
# | 5   | 201 to 500     |   755   |
# | 6   | 501 to 1,000   |   954   |
# | 7   |1,001 to 5,000  |   2135  |
# | 8   |5,001 to 10,000 |   734   |
# | 9   |  10,000+       |   1360  |

# %%
sb.catplot(y='employees', data=df, kind='count')

# %%
f, axes = plt.subplots(figsize=(15, 10))
sb.boxplot(x = 'employees', y = 'rating', data = df).set(title='Rating v.s. Company size')
# Out:
# [Text(0.5, 1.0, 'Rating v.s. Company size')]

# %% [markdown]
# ### Discoveries:
# It seems like the small (1 employee) and large (10,000+) size of companies have slight higher ratings compared.
# > Let's ignore small size company since the ratings may from the founder himself / herself, lacking objectivity, and the data size is quite small <br>
# > For large company having higer ratings, we wonder whether the higer company revenue would lead to better ratings.

# %% [markdown]
# ### 2.1. Revenue (Company Financial Condition)
# | Label  |Description       | Count       |
# | :---                | :------: | :--------: |
# | 1   |  less than 1M (USD)  |    233 |
# | 2   |  1 to 5M (USD)      |    298 |
# | 3   |  5M to 25M (USD)    |    667 |
# | 4   |  25M to 100M (USD) |    1127|
# | 5   |  100M to 500M (USD) |   1541 |
# | 6   |  500M to 1B (USD)   |   626  |
# | 7   |  1B to 5B (USD)     |   1169 |
# | 8   |  5B to 10B (USD)    |   306  |
# | 9   |  more than 10B (USD) |   509  |

# %%
sb.catplot(y='revenue', data=df, kind='count')

# %%
f, axes = plt.subplots(figsize=(15, 10))
sb.boxplot(x = 'revenue', y = 'rating', data = df).set(title='Rating v.s. Company Revenue')
# Out:
# [Text(0.5, 1.0, 'Rating v.s. Company Revenue')]

# %% [markdown]
# ### Discoveries:
# There is slight increase of ratings when revenue increases, however, due to the uneven distribution of number of datapoints among different categories, this finding may not be objective. And the difference is not very distinguishing.

# %% [markdown]
# ### 2.3. Industry
# We then explore the difference of ratings among industries, and relate them with other features
# - Financials
# - Leisure
# - Healthcare_NGO
# - Telecomm
# - Govt_Services
# - Tech
# - Commodities
# - FNB
# - Retail
# - Real_Estate

# %%
sb.countplot(y='industry', data=df, order=df['industry'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='industry'>

# %%
sb.catplot(x = 'industry', y = 'rating', data = df, height=10, aspect=1.25, kind='box', order=df['industry'].value_counts().index).set(title='Rating v.s. Industry')

# %% [markdown]
# # Correlation between variables and rating by industry

# %%
industries = ['Commodities', 'Financials', 'Govt_Services', 'Healthcare_NGO',
       'Leisure', 'Tech', 'Telecomm', 'Real_Estate', 'Retail', 'FNB']
variables = ['avg_salary', 'ceo_approval', 'Work/Life Balance', 'Compensation/Benefits', 'Job Security/Advancement', 
               'Management', 'Culture']

industryCorrDict = {}
for var in variables:
    industryCorrDict[var] = pd.DataFrame()
    
for industry in industries:
    df_temp = df[df['industry'] == industry]
    
    for var in variables:
        corr = df_temp['rating'].corr(df_temp[var])
        industryCorrDict[var][industry] = [corr]

# %%
fig, axes = plt.subplots(7, figsize=(50,150))

sb.set_context("paper", rc={"font.size":64,"axes.titlesize":64,"axes.labelsize":64, "xtick.labelsize":64, "ytick.labelsize": 64})
for i, var in enumerate(variables):
    sb.barplot(data=industryCorrDict[var].reindex(industryCorrDict[var].mean().sort_values().index, axis=1), ax=axes[i], 
               orient='h')
    axes[i].set_title("Correlation of rating with " + var)

# %% [markdown]
# # Correlation between happiness and rating by industry

# %%
happiness = ['Work Happiness Score', 'Appreciation', 'Purpose', 'Learning', 'Support', 'Achievement', 'Trust', 'Energy', 
            'Inclusion', 'Belonging', 'Compensation', 'Flexibility']

for var in happiness:
    industryCorrDict[var] = pd.DataFrame()
    
for industry in industries:
    df_temp = df2[df2['industry'] == industry]
    
    for var in happiness:
        corr = df_temp['rating'].corr(df_temp[var])
        industryCorrDict[var][industry] = [corr]

# %%
fig, axes = plt.subplots(12, figsize=(50,150))

sb.set_context("paper", rc={"font.size":64,"axes.titlesize":64,"axes.labelsize":64, "xtick.labelsize":64, "ytick.labelsize": 64})
for i, var in enumerate(happiness):
    sb.barplot(data=industryCorrDict[var].reindex(industryCorrDict[var].mean().sort_values().index, axis=1), ax=axes[i], 
               orient='h')
    axes[i].set_title("Correlation of rating with " + var)
